# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
import json

# Creating jsons for CLIP

train_dir = '/content/drive/MyDrive/Applied CV Project/freiburg_groceries_scenes/images/train'
test_dir = '/content/drive/MyDrive/Applied CV Project/freiburg_groceries_scenes/images/test'
labels_path = '/content/drive/MyDrive/Applied CV Project/freiburg_groceries_scenes/labels.txt'

labels_dict = {}
with open(labels_path, 'r') as file:
  for line in file:
    parts = line.strip().split(';')
    if len(parts) == 2:
      image_id, labels = parts
      labels_dict[image_id] = labels.split(',') # split labels by ',' to create list

labels_dict
# Out:
# {'scene_000_0': [' CEREAL',
#   'HONEY',
#   'JAM',
#   'COFFEE',
#   'TEA',
#   'OIL',
#   'VINEGAR',
#   'SUGAR',
#   'SPICES',
#   'RICE',
#   'FISH',
#   'CORN',
#   'BEANS',
#   'PASTA',
#   'TOMATO_SAUCE'],
#  'scene_000_1': [' CEREAL',
#   'HONEY',
#   'JAM',
#   'COFFEE',
#   'TEA',
#   'OIL',
#   'VINEGAR',
#   'SUGAR',
#   'SPICES',
#   'RICE',
#   'FISH',
#   'CORN',
#   'BEANS',
#   'PASTA',
#   'TOMATO_SAUCE'],
#  'scene_001_0': [' CEREAL',
#   'HONEY',
#   'JAM',
#   'MILK',
#   'COFFEE',
#   'TEA',
#   'OIL',
#   'VINEGAR',
#   'SUGAR',
#   'SPICES',
#   'RICE',
#   'FISH',
#   'CORN',
#   'BEANS',
#   'PASTA',
#   'TOMATO_SAUCE'],
#  'scene_001_1': [' CEREAL',
#   'HONEY',
#   'JAM',
#   'MILK',
#   'COFFEE',
#   'TEA',
#   'OIL',
#   'VINEGAR',
#   'SUGAR',
#   'SPICES',
#   'RICE',
#   'FISH',
#   'CORN',
#   'BEANS',
#   'PASTA',
#   'TOMATO_SAUCE'],
#  'scene_002_0': [' TEA',
#   'CEREAL',
#   'HONEY',
#   'COFFEE',
#   'MILK',
#   'PASTA',
#   'RICE',
#   'SPICES',
#   'TOMATO_SAUCE',
#   'FOSH',
#   'BEANS',
#   'CORN',
#   'OIL',
#   'VINEGAR',
#   'SUGAR'],
#  'scene_002_1': [' TEA',
#   'CEREAL',
#   'HONEY',
#   'COFFEE',
#   'MILK',
#   'PASTA',
#   'RICE',
#   'SPICES',
#   'TOMATO_SAUCE',
#   'FOSH',
#   'BEANS',
#   'CORN',
#   'OIL',
#   'VINEGAR',
#   'SUGAR'],
#  'scene_003_0': [' PASTA',
#   'RICE',
#   'MILK',
#   'JAM',
#   'HONEY',
#   'SUGAR',
#   'COFFEE',
#   'TEA',
#   'CEREAL',
#   'VINEGAR',
#   'OIL',
#   'BEANS',
#   'SPICES',
#   'TOMATO_SAUCE',
#   'FISH'],
#  'scene_003_1': [' PASTA',
#   'RICE',
#   'MILK',
#   'JAM',
#   'HONEY',
#   'SUGAR',
#   'COFFEE',
#   'TEA',
#   'CEREAL',
#   'VINEGAR',
#   'OIL',
#   'BEANS',
#   'SPICES',
#   'TOMATO_SAUCE',
#   'FISH'],
#  'scene_004_0': [' SODA',
#   'JUICE',
#   'MILK',
#   'JAM',
#   'HONEY',
#   'SUGAR',
#   'COFFEE',
#   'CAKE',
#   'FLOUR',
#   'VINEGAR',
#   'OIL',
#   'CORN',
#   'SPICES',
#   'FISH',
#   'TOMATO_SAUCE'],
#  'scene_004_1': [' SODA',
#   'JUICE',
#   'MILK',
#   'JAM',
#   'HONEY',
#   'SUGAR',
#   'COFFEE',
#   'CAKE',
#   'FLOUR',
#   'VINEGAR',
#   'OIL',
#   'CORN',
#   'SPICES',
#   'FISH',
#   'TOMATO_SAUCE'],
#  'scene_005_0': [' SODA', 'JUICE', 'MILK', 'JAM', 'HONEY', 'SUGAR', 'COFFEE'],
#  'scene_005_1': [' SODA', 'JUICE', 'MILK', 'JAM', 'HONEY', 'SUGAR', 'COFFEE'],
#  'scene_006_0': [' PASTA',
#   'TOMATO_SAUCE',
#   'OIL',
#   'BEANS',
#   'CORN',
#   'SPICES',
#   'FISH'],
#  'scene_006_1': [' PASTA',
#   'TOMATO_SAUCE',
#   'OIL',
#   'BEANS',
#   'CORN',
#   'SPICES',
#   'FISH'],
#  'scene_007_0': [' CHOCOLATE', 'CANDY', 'JUICE', 'NUTS', 'CAKE'],
#  'scene_007_1': [' CHOCOLATE', 'CANDY', 'JUICE', 'NUTS', 'CAKE'],
#  'scene_008_0': [' CHOCOLATE', ' CANDY', 'SODA', 'JUICE', 'CHIPS', 'NUTS'],
#  'scene_008_1': [' CHOCOLATE', ' CANDY', 'SODA', 'JUICE', 'CHIPS', 'NUTS'],
#  'scene_009_0': [' COFFEE',
#   'CANDY',
#   'CHOCOLATE',
#   'JAM',
#   'SODA',
#   'JUICE',
#   'CEREAL',
#   'CHIPS'],
#  'scene_009_1': [' COFFEE',
#   'CANDY',
#   'CHOCOLATE',
#   'JAM',
#   'SODA',
#   'JUICE',
#   'CEREAL',
#   'CHIPS'],
#  'scene_010_0': [' TEA',
#   'COFFEE',
#   'JUICE',
#   'SODA',
#   'JAM',
#   'CAKE',
#   'FLOUR',
#   'NUTS',
#   'CHIPS'],
#  'scene_010_1': [' TEA',
#   'COFFEE',
#   'JUICE',
#   'SODA',
#   'JAM',
#   'CAKE',
#   'FLOUR',
#   'NUTS',
#   'CHIPS'],
#  'scene_011_0': [' CHOCOLATE',
#   'CANDY',
#   'JUICE',
#   'SODA',
#   'WATER',
#   'JAM',
#   'CAKE',
#   'FLOUR',
#   'SUGAR',
#   'MILK'],
#  'scene_011_1': [' CHOCOLATE',
#   'CANDY',
#   'JUICE',
#   'SODA',
#   'WATER',
#   'JAM',
#   'CAKE',
#   'FLOUR',
#   'SUGAR',
#   'MILK'],
#  'scene_012_0': [' CHIPS',
#   'CANDY',
#   'CHOCOLATE',
#   'SODA',
#   'WATER',
#   'NUTS',
#   'JUICE'],
#  'scene_012_1': [' CHIPS',
#   'CANDY',
#   'CHOCOLATE',
#   'SODA',
#   'WATER',
#   'NUTS',
#   'JUICE'],
#  'scene_013_0': [' CHIPS', 'WATER', 'SODA', 'JUICE'],
#  'scene_013_1': [' CHIPS', 'WATER', 'SODA', 'JUICE'],
#  'scene_014_0': [' CEREAL', 'JAM', 'HONEY', 'MILK', 'TEA', 'COFFEE'],
#  'scene_014_1': [' CEREAL', 'JAM', 'HONEY', 'MILK', 'TEA', 'COFFEE'],
#  'scene_015_0': [' PASTA',
#   'RICE',
#   'BEANS',
#   'TOMATO_SAUCE',
#   'CORN',
#   'FISH',
#   'SPICES'],
#  'scene_015_1': [' PASTA',
#   'RICE',
#   'BEANS',
#   'TOMATO_SAUCE',
#   'CORN',
#   'FISH',
#   'SPICES'],
#  'scene_016_0': [' WATER',
#   'JUICE',
#   'SODA',
#   'PASTA',
#   'OIL',
#   'VINEGAR',
#   'BEANS',
#   'CORN',
#   'TOMATO_SAUCE'],
#  'scene_016_1': [' WATER',
#   'JUICE',
#   'SODA',
#   'PASTA',
#   'OIL',
#   'VINEGAR',
#   'BEANS',
#   'CORN',
#   'TOMATO_SAUCE'],
#  'scene_017_0': [' JUICE', 'SODA', 'WATER'],
#  'scene_017_1': [' JUICE', 'SODA', 'WATER'],
#  'scene_018_0': [' CAKE', 'FLOUR', 'TEA', 'MILK'],
#  'scene_018_1': [' CAKE', 'FLOUR', 'TEA', 'MILK'],
#  'scene_019_0': [' JAM', 'CEREAL', 'COFFEE', 'TEA'],
#  'scene_019_1': [' JAM', 'CEREAL', 'COFFEE', 'TEA'],
#  'scene_020_0': [' PASTA', 'TOMATO_SAUCE', 'CORN', 'BEANS', 'FISH'],
#  'scene_020_1': [' PASTA', 'TOMATO_SAUCE', 'CORN', 'BEANS', 'FISH'],
#  'scene_021_0': [' CORN',
#   'BEANS',
#   'RICE',
#   'FISH',
#   'PASTA',
#   'TEA',
#   'NUTS',
#   'MILK',
#   'CEREAL'],
#  'scene_021_1': [' CORN',
#   'BEANS',
#   'RICE',
#   'FISH',
#   'PASTA',
#   'TEA',
#   'NUTS',
#   'MILK',
#   'CEREAL'],
#  'scene_022_0': [' CHIPS', 'JAM', 'CANDY', 'CHOCOLATE'],
#  'scene_022_1': [' CHIPS', 'JAM', 'CANDY', 'CHOCOLATE'],
#  'scene_023_0': [' CHIPS', 'SODA', 'CANDY', 'SPICES'],
#  'scene_023_1': [' CHIPS', 'SODA', 'CANDY', 'SPICES'],
#  'scene_024_0': [' JUICE'],
#  'scene_024_1': [' JUICE'],
#  'scene_025_0': [' CEREAL', 'JUICE'],
#  'scene_025_1': [' CEREAL', 'JUICE'],
#  'scene_026_0': [' COFFEE', 'WATER', 'MILK'],
#  'scene_026_1': [' COFFEE', 'WATER', 'MILK'],
#  'scene_027_0': [' CANDY', 'OIL', 'VINEGAR', 'FLOUR', 'FISH', 'MILK'],
#  'scene_027_1': [' CANDY', 'OIL', 'VINEGAR', 'FLOUR', 'FISH', 'MILK'],
#  'scene_028_0': [' COFFEE', 'CHOCOLATE', 'FLOUR', 'PASTA', 'SUGAR'],
#  'scene_028_1': [' COFFEE', 'CHOCOLATE', 'FLOUR', 'PASTA', 'SUGAR'],
#  'scene_029_0': [' NUTS', 'TOMATO_SAUCE', 'WATER', 'SALT', 'JAM'],
#  'scene_029_1': [' NUTS', 'TOMATO_SAUCE', 'WATER', 'SALT', 'JAM'],
#  'scene_030_0': [' PASTA', 'TEA', 'HONEY', 'SODA'],
#  'scene_030_1': [' PASTA', 'TEA', 'HONEY', 'SODA'],
#  'scene_031_0': [' PASTA',
#   'TEA',
#   'CHOCOLATE',
#   'MILK',
#   'JUICE',
#   'CHIPS',
#   'SODA'],
#  'scene_031_1': [' PASTA',
#   'TEA',
#   'CHOCOLATE',
#   'MILK',
#   'JUICE',
#   'CHIPS',
#   'SODA'],
#  'scene_032_0': [' RICE', 'PASTA', 'NUTS', 'JUICE', 'CHIPS'],
#  'scene_032_1': [' RICE', 'PASTA', 'NUTS', 'JUICE', 'CHIPS'],
#  'scene_033_0': [' CEREAL',
#   'CAKE',
#   'JUICE',
#   'CANDY',
#   'WATER',
#   'JUICE',
#   'CORN',
#   'SPICES',
#   'CHIPS'],
#  'scene_033_1': [' CEREAL',
#   'CAKE',
#   'JUICE',
#   'CANDY',
#   'WATER',
#   'JUICE',
#   'CORN',
#   'SPICES',
#   'CHIPS'],
#  'scene_034_0': [' CEREAL',
#   'SPICES',
#   'JAM',
#   'JUICE',
#   'SUGAR',
#   'WATER',
#   'CANDY',
#   'MILK',
#   'CORN',
#   'SPICES',
#   'PASTA'],
#  'scene_034_1': [' CEREAL',
#   'SPICES',
#   'JAM',
#   'JUICE',
#   'SUGAR',
#   'WATER',
#   'CANDY',
#   'MILK',
#   'CORN',
#   'SPICES',
#   'PASTA'],
#  'scene_035_0': [' CEREAL',
#   'BEANS',
#   'TOMATO_SAUCE',
#   'CANDY',
#   'FISH',
#   'FLOUR',
#   'TEA',
#   'CHOCOLATE',
#   'COFFEE',
#   'SUGAR',
#   'WATER',
#   'MILK',
#   'CORN',
#   'PASTA',
#   'SPICES'],
#  'scene_035_1': [' CEREAL',
#   'BEANS',
#   'TOMATO_SAUCE',
#   'CANDY',
#   'FISH',
#   'FLOUR',
#   'TEA',
#   'CHOCOLATE',
#   'COFFEE',
#   'SUGAR',
#   'WATER',
#   'MILK',
#   'CORN',
#   'PASTA',
#   'SPICES'],
#  'scene_036_0': [' CEREAL',
#   'BEANS',
#   'TOMATO_SAUCE',
#   'CANDY',
#   'FISH',
#   'FLOUR',
#   'TEA',
#   'CHOCOLATE',
#   'COFFEE',
#   'SUGAR',
#   'WATER',
#   'MILK',
#   'CORN',
#   'PASTA',
#   'SODA'],
#  'scene_036_1': [' CEREAL',
#   'BEANS',
#   'TOMATO_SAUCE',
#   'CANDY',
#   'FISH',
#   'FLOUR',
#   'TEA',
#   'CHOCOLATE',
#   'COFFEE',
#   'SUGAR',
#   'WATER',
#   'MILK',
#   'CORN',
#   'PASTA',
#   'SODA']}

# %%
def create_json_for_dataset(dataset_dir, dataset_type):
  dataset = []

  base_dir = "/content/drive/MyDrive/Applied CV Project/freiburg_groceries_scenes"

  for file_name in os.listdir(dataset_dir):

    if not file_name.endswith(".png"): # filter out non-png images
      continue

    image_id = os.path.splitext(file_name)[0]
    if image_id in labels_dict:
      data_entry = {
          "image_id" : image_id,
          "file_path": os.path.join('./',os.path.relpath(dataset_dir, base_dir),file_name),
          "labels" : [label.replace("_", " ").lower() for label in labels_dict[image_id]]
      }
      dataset.append(data_entry)

  # Write out json
  json_file_path = os.path.join(base_dir,  f'{dataset_type}_data.json')
  with open(json_file_path, 'w') as json_file:
    json.dump(dataset, json_file)

  print(f"Created {json_file_path}")

# %%
create_json_for_dataset(train_dir,"train")
create_json_for_dataset(test_dir,"test")
# Out:
# Created /content/drive/MyDrive/Applied CV Project/freiburg_groceries_scenes/train_data.json
# Created /content/drive/MyDrive/Applied CV Project/freiburg_groceries_scenes/test_data.json

# %%
# CLIP_training_instructions
instructions = "All image paths are relative to the root directory, i.e., freiburg_groceries_scenes"
file_path = "/content/drive/MyDrive/Applied CV Project/freiburg_groceries_scenes/instructions.txt"

with open(file_path, 'w') as f:
  f.write(instructions)

# %% [markdown]
# JSON creation for freiburg_groceries_dataset

# %%
def create_json_for_dataset_freiburg_groceries(dataset_dir, dataset_type):
  dataset = []

  base_dir = "/content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset"

  # iterate through all the individual folders and find the dataset_type
  categories = [f for f in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, f))]
  categories_paths = [os.path.join(base_dir, x) for x in categories]

  for category in categories:
    category_path = os.path.join(base_dir, category, dataset_type)
    print(category_path)

    if os.path.exists(category_path):
      for file_name in os.listdir(category_path):
        if not file_name.endswith(".png"): # filter out non-png images
          continue

        image_id = os.path.splitext(file_name)[0]
        data_entry = {
            "image_id" : image_id,
            "file_path": os.path.join('./',os.path.relpath(category_path, base_dir),file_name),
            "labels" : [category.replace("_", " ").lower()] # just the directory name
        }
        dataset.append(data_entry)
    print(category)

  # Write out json
  json_file_path = os.path.join(base_dir,  f'{dataset_type}_data.json')
  with open(json_file_path, 'w') as json_file:
    json.dump(dataset, json_file)

  print(f"Created {json_file_path}")

# %%
create_json_for_dataset_freiburg_groceries("/content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset", "test")
create_json_for_dataset_freiburg_groceries("/content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset", "train")
# Out:
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/FLOUR/test
# FLOUR
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/SUGAR/test
# SUGAR
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/WATER/test
# WATER
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/NUTS/test
# NUTS
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/RICE/test
# RICE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CHIPS/test
# CHIPS
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/TOMATO_SAUCE/test
# TOMATO_SAUCE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CHOCOLATE/test
# CHOCOLATE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/VINEGAR/test
# VINEGAR
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/MILK/test
# MILK
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/SODA/test
# SODA
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/PASTA/test
# PASTA
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/TEA/test
# TEA
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/HONEY/test
# HONEY
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/JUICE/test
# JUICE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/BEANS/test
# BEANS
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/COFFEE/test
# COFFEE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CEREAL/test
# CEREAL
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CORN/test
# CORN
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/JAM/test
# JAM
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CANDY/test
# CANDY
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/FISH/test
# FISH
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CAKE/test
# CAKE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/SPICES/test
# SPICES
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/OIL/test
# OIL
# Created /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/test_data.json
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/FLOUR/train
# FLOUR
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/SUGAR/train
# SUGAR
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/WATER/train
# WATER
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/NUTS/train
# NUTS
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/RICE/train
# RICE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CHIPS/train
# CHIPS
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/TOMATO_SAUCE/train
# TOMATO_SAUCE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CHOCOLATE/train
# CHOCOLATE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/VINEGAR/train
# VINEGAR
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/MILK/train
# MILK
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/SODA/train
# SODA
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/PASTA/train
# PASTA
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/TEA/train
# TEA
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/HONEY/train
# HONEY
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/JUICE/train
# JUICE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/BEANS/train
# BEANS
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/COFFEE/train
# COFFEE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CEREAL/train
# CEREAL
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CORN/train
# CORN
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/JAM/train
# JAM
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CANDY/train
# CANDY
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/FISH/train
# FISH
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/CAKE/train
# CAKE
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/SPICES/train
# SPICES
# /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/OIL/train
# OIL
# Created /content/drive/MyDrive/Applied CV Project/freiburg_groceries_dataset/train_data.json

# %%
# CLIP_training_instructions
instructions = "All image paths are relative to the root directory, i.e., freiburg_groceries_dataset"
file_path = "/content/drive/MyDrive/Applied CV Project/freiburg_groceries_scenes/instructions.txt"

with open(file_path, 'w') as f:
  f.write(instructions)

# %% [markdown]
# Fruits-360 Json

# %%
import os, json

# %%
import os, json, re
def create_json_for_dataset_fruits360(dataset_type):
  num_imgs = 0
  dataset = []

  base_dir = f"/content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/{dataset_type}"

  # iterate through all the individual folders and find the dataset_type
  categories = [f for f in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, f))]
  # categories_paths = [os.path.join(base_dir, x) for x in categories]

  # print(categories_paths)
  # return

  for category in categories:
    category_path = os.path.join(base_dir, category)
    # print(category_path)
    # return

    if os.path.exists(category_path):
      for file_name in os.listdir(category_path):
        num_imgs += 1
        if not file_name.endswith(".jpg"): # filter out non-jpg images
          continue
        # print(file_path)

        cleaned_category = re.sub(r'\d+', '', category).strip().replace("_", " ").lower()
        image_id = os.path.splitext(file_name)[0]
        data_entry = {
            "image_id" : image_id,
            "file_path": os.path.join('./',os.path.relpath(category_path, base_dir),file_name),
            "labels" : [cleaned_category] # just the directory name
        }
        dataset.append(data_entry)
        # print(data_entry)
    # print(category)

  # Write out json
  json_file_path = os.path.join(base_dir,  f'{dataset_type}_data.json')
  with open(json_file_path, 'w') as json_file:
    json.dump(dataset, json_file)

  print(f"Created {json_file_path}")
  print(num_imgs)

# %%
create_json_for_dataset_fruits360('Test')
# Out:
# Created /content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Test/Test_data.json
# 22688

# %%
create_json_for_dataset_fruits360('Training')
# Out:
# Created /content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Training/Training_data.json
# 67882

# %% [markdown]
# Checking for which files/folders have not bee successfully uploaded.

# %%
import os

def list_drive_files_with_paths(drive_base_path):
    drive_files = []
    for root, dirs, files in os.walk(drive_base_path):
        for file in files:
            if file.endswith(".jpg"):
                # Construct the path relative to the base directory in Google Drive
                relative_path = os.path.relpath(root, drive_base_path)
                drive_files.append(os.path.join('Training/',relative_path, file))
    return drive_files

# %%
drive_base_path = "/content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Training"  # Adjust to your Google Drive structure
drive_files = list_drive_files_with_paths(drive_base_path)
print(drive_files)
print(len(drive_files))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
local_file_path = "/content/local_files_list.txt"
with open(local_file_path,'r') as file:
  local_files = ['Training/'+line.strip() for line in file]
print(local_files[0])
# Out:
# Training/Tomato 4/r_236_100.jpg

# %%
missing_files = [file for file in local_files if file not in drive_files]
print(f"Number of missing files: {len(missing_files)}")
# Out:
# Number of missing files: 492

# %%
# missing_files = [file for file in local_files if file not in drive_files]
print(missing_files)
missing_folders = set()

for file_path in missing_files:
  folder_name = file_path.split('/')[1]
  missing_folders.add(folder_name)

# with open('/content/missing_folder.txt','w') as f:
#   for folder in sorted(missing_folders):
#     f.write("%s\n" % folder)
# Out:
# ['Training/Peach Flat/r_236_100.jpg', 'Training/Peach Flat/247_100.jpg', 'Training/Peach Flat/r_226_100.jpg', 'Training/Peach Flat/257_100.jpg', 'Training/Peach Flat/r_150_100.jpg', 'Training/Peach Flat/121_100.jpg', 'Training/Peach Flat/r_140_100.jpg', 'Training/Peach Flat/131_100.jpg', 'Training/Peach Flat/198_100.jpg', 'Training/Peach Flat/188_100.jpg', 'Training/Peach Flat/18_100.jpg', 'Training/Peach Flat/r_132_100.jpg', 'Training/Peach Flat/143_100.jpg', 'Training/Peach Flat/r_122_100.jpg', 'Training/Peach Flat/153_100.jpg', 'Training/Peach Flat/r_254_100.jpg', 'Training/Peach Flat/225_100.jpg', 'Training/Peach Flat/r_244_100.jpg', 'Training/Peach Flat/235_100.jpg', 'Training/Peach Flat/300_100.jpg', 'Training/Peach Flat/r_209_100.jpg', 'Training/Peach Flat/278_100.jpg', 'Training/Peach Flat/r_219_100.jpg', 'Training/Peach Flat/310_100.jpg', 'Training/Peach Flat/268_100.jpg', 'Training/Peach Flat/r_25_100.jpg', 'Training/Peach Flat/r_313_100.jpg', 'Training/Peach Flat/r_303_100.jpg', 'Training/Peach Flat/27_100.jpg', 'Training/Peach Flat/11_100.jpg', 'Training/Peach Flat/285_100.jpg', 'Training/Peach Flat/295_100.jpg', 'Training/Peach Flat/r_192_100.jpg', 'Training/Peach Flat/r_182_100.jpg', 'Training/Peach Flat/r_13_100.jpg', 'Training/Peach Flat/r_149_100.jpg', 'Training/Peach Flat/138_100.jpg', 'Training/Peach Flat/r_159_100.jpg', 'Training/Peach Flat/128_100.jpg', 'Training/Peach Flat/181_100.jpg', 'Training/Peach Flat/191_100.jpg', 'Training/Peach Flat/r_296_100.jpg', 'Training/Peach Flat/r_286_100.jpg', 'Training/Peach Flat/2_100.jpg', 'Training/Peach Flat/r_272_100.jpg', 'Training/Peach Flat/203_100.jpg', 'Training/Peach Flat/r_262_100.jpg', 'Training/Peach Flat/213_100.jpg', 'Training/Peach Flat/r_114_100.jpg', 'Training/Peach Flat/165_100.jpg', 'Training/Peach Flat/r_104_100.jpg', 'Training/Peach Flat/175_100.jpg', 'Training/Peach Flat/r_176_100.jpg', 'Training/Peach Flat/107_100.jpg', 'Training/Peach Flat/r_166_100.jpg', 'Training/Peach Flat/117_100.jpg', 'Training/Peach Flat/r_210_100.jpg', 'Training/Peach Flat/319_100.jpg', 'Training/Peach Flat/261_100.jpg', 'Training/Peach Flat/309_100.jpg', 'Training/Peach Flat/r_200_100.jpg', 'Training/Peach Flat/271_100.jpg', 'Training/Peach Flat/r_12_100.jpg', 'Training/Peach Flat/294_100.jpg', 'Training/Peach Flat/284_100.jpg', 'Training/Peach Flat/10_100.jpg', 'Training/Peach Flat/r_183_100.jpg', 'Training/Peach Flat/r_193_100.jpg', 'Training/Peach Flat/190_100.jpg', 'Training/Peach Flat/180_100.jpg', 'Training/Peach Flat/r_287_100.jpg', 'Training/Peach Flat/r_297_100.jpg', 'Training/Peach Flat/129_100.jpg', 'Training/Peach Flat/r_158_100.jpg', 'Training/Peach Flat/139_100.jpg', 'Training/Peach Flat/r_148_100.jpg', 'Training/Peach Flat/212_100.jpg', 'Training/Peach Flat/r_263_100.jpg', 'Training/Peach Flat/202_100.jpg', 'Training/Peach Flat/r_273_100.jpg', 'Training/Peach Flat/174_100.jpg', 'Training/Peach Flat/r_105_100.jpg', 'Training/Peach Flat/164_100.jpg', 'Training/Peach Flat/r_115_100.jpg', 'Training/Peach Flat/116_100.jpg', 'Training/Peach Flat/r_167_100.jpg', 'Training/Peach Flat/106_100.jpg', 'Training/Peach Flat/r_177_100.jpg', 'Training/Peach Flat/270_100.jpg', 'Training/Peach Flat/308_100.jpg', 'Training/Peach Flat/r_201_100.jpg', 'Training/Peach Flat/260_100.jpg', 'Training/Peach Flat/r_211_100.jpg', 'Training/Peach Flat/318_100.jpg', 'Training/Peach Flat/189_100.jpg', 'Training/Peach Flat/199_100.jpg', 'Training/Peach Flat/256_100.jpg', 'Training/Peach Flat/r_227_100.jpg', 'Training/Peach Flat/246_100.jpg', 'Training/Peach Flat/r_237_100.jpg', 'Training/Peach Flat/130_100.jpg', 'Training/Peach Flat/r_141_100.jpg', 'Training/Peach Flat/120_100.jpg', 'Training/Peach Flat/r_151_100.jpg', 'Training/Peach Flat/r_2_100.jpg', 'Training/Peach Flat/152_100.jpg', 'Training/Peach Flat/r_123_100.jpg', 'Training/Peach Flat/142_100.jpg', 'Training/Peach Flat/r_133_100.jpg', 'Training/Peach Flat/234_100.jpg', 'Training/Peach Flat/r_245_100.jpg', 'Training/Peach Flat/22 ...

# %%
print(missing_folders)
# Out:
# {'Peach Flat'}

# %%
print(len(missing_folders))
# Out:
# 1

# %%
# Find extra files in Google Drive
extra_files = [file for file in drive_files if file not in local_files]

# %%
# Extract folder names from the paths of extra files
extra_folders = set()  # Use a set to avoid duplicate folder names
for file_path in extra_files:
    # This splits the path and extracts the second component
    # Adjust the index if necessary based on your path structure
    folder_name = file_path.split('/')[1]  # Adjust if your structure is different
    extra_folders.add(folder_name)

print(extra_folders)
# Out:
# {'Nut Pecan', 'Peach Flat (1)', 'Granadilla', 'Kohlrabi', 'Fig', 'Onion White', 'Tamarillo', 'Pepper Red'}

# %%
import os

def list_all_directories(base_path):
    all_dirs = {}
    for root, dirs, files in os.walk(base_path):
        # Store the list of directories in this path
        if dirs:  # If there are any directories under 'root'
            all_dirs[root] = dirs
    return all_dirs

# Adjust the base path to where your directories start
base_path = '/content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Training'
all_dirs = list_all_directories(base_path)

# %%
all_dirs
# Out:
# {'/content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Training': ['Tomato 4',
#   'Banana Lady Finger',
#   'Apple Red Delicious',
#   'Pear Red',
#   'Tomato 3',
#   'Huckleberry',
#   'Blueberry',
#   'Melon Piel de Sapo',
#   'Strawberry',
#   'Cherry 1',
#   'Dates',
#   'Pomegranate',
#   'Avocado',
#   'Nut Forest',
#   'Tomato 2',
#   'Carambula',
#   'Granadilla',
#   'Potato Red Washed',
#   'Tamarillo',
#   'Kohlrabi',
#   'Cherry Wax Yellow',
#   'Pepper Red',
#   'Guava',
#   'Lemon',
#   'Fig',
#   'Kiwi',
#   'Apple Golden 2',
#   'Ginger Root',
#   'Pear Stone',
#   'Apple Red 1',
#   'Pitahaya Red',
#   'Raspberry',
#   'Strawberry Wedge',
#   'Nut Pecan',
#   'Mandarine',
#   'Quince',
#   'Pear Monster',
#   'Cauliflower',
#   'Apple Golden 3',
#   'Redcurrant',
#   'Pepper Yellow',
#   'Apple Red Yellow 1',
#   'Chestnut',
#   'Cherry Rainier',
#   'Cucumber Ripe 2',
#   'Banana Red',
#   'Plum',
#   'Physalis',
#   'Grape Pink',
#   'Maracuja',
#   'Cucumber Ripe',
#   'Potato Sweet',
#   'Hazelnut',
#   'Nectarine',
#   'Cantaloupe 2',
#   'Mangostan',
#   'Pepper Orange',
#   'Watermelon',
#   'Clementine',
#   'Lychee',
#   'Pear Kaiser',
#   'Cherry Wax Black',
#   'Cherry 2',
#   'Pineapple Mini',
#   'Rambutan',
#   'Mango',
#   'Tomato Yellow',
#   'Onion White',
#   'Apple Braeburn',
#   'Grape White',
#   'Tomato Maroon',
#   'Onion Red Peeled',
#   'Potato White',
#   'Apple Crimson Snow',
#   'Cocos',
#   'Tomato 1',
#   'Passion Fruit',
#   'Mulberry',
#   'Corn Husk',
#   'Potato Red',
#   'Avocado ripe',
#   'Apple Granny Smith',
#   'Kumquats',
#   'Beetroot',
#   'Corn',
#   'Grape White 3',
#   'Apricot',
#   'Eggplant',
#   'Grape White 4',
#   'Tomato Heart',
#   'Limes',
#   'Grape White 2',
#   'Apple Pink Lady',
#   'Plum 3',
#   'Tomato not Ripened',
#   'Salak',
#   'Peach 2',
#   'Apple Golden 1',
#   'Banana',
#   'Grapefruit Pink',
#   'Pomelo Sweetie',
#   'Pear Williams',
#   'Apple Red Yellow 2',
#   'Plum 2',
#   'Grape Blue',
#   'Physalis with Husk',
#   'Pepino',
#   'Tangelo',
#   'Lemon Meyer',
#   'Peach',
#   'Apple Red 2',
#   'Tomato Cherry Red',
#   'Pear 2',
#   'Walnut',
#   'Nectarine Flat',
#   'Pepper Green',
#   'Apple Red 3',
#   'Orange',
#   'Cherry Wax Red',
#   'Cactus fruit',
#   'Apple Red 3 (1)',
#   'Papaya',
#   'Pear Forelle',
#   'Grapefruit White',
#   'Mango Red',
#   'Kaki',
#   'Pear Abate',
#   'Pear',
#   'Peach Flat (1)',
#   'Pineapple',
#   'Onion Red',
#   'Cantaloupe 1'],
#  '/content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Training/Pear Monster': ['Pear 2']}

# %%
import os

def find_directories_with_subdirectories(base_path):
    # This will store directories that contain other directories
    directories_with_subdirectories = []

    for root, dirs, files in os.walk(base_path):
        # If this directory contains other directories, note it down
        if dirs:  # 'dirs' is a list of directory names within 'root'
            directories_with_subdirectories.append(root)

    return directories_with_subdirectories

# Set the base directory path
base_path = '/content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Training'  # Adjust to your base directory
directories_with_subdirectories = find_directories_with_subdirectories(base_path)

# Print out the directories that contain other directories
print("Directories containing other directories:")
for directory in directories_with_subdirectories:
    print(directory)
# Out:
# Directories containing other directories:
# /content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Training

# %%
import json

# Assuming 'data.json' is your JSON file
with open('/content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Training/Training_data.json', 'r') as file:
    dataset = json.load(file)


# List to hold entries that are not in the second level
incorrect_paths = []

for item in dataset:
    # Count the number of slashes in the file_path
    num_slashes = item['file_path'].count('/')

    # Check if there are more than two slashes (adjust this number based on your base path)
    if num_slashes > 2:
        incorrect_paths.append(item)

# Print out or process entries with incorrect paths
for item in incorrect_paths:
    print(item)

print(incorrect_paths)
# Out:
# []

# %% [markdown]
# March 31, 2024: Updating the train json for fruits 360 to rectify bugs.

# %%
import json, os

base_dir = f"/content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Training"

# Load in the json file
with open('/content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Training/Training_data.json', 'r') as file:
    dataset = json.load(file)

for item in dataset:
  if "Peach Flat (1)" in item["file_path"]:
    item["file_path"] = item["file_path"].replace("Peach Flat (1)", "Peach Flat")

  if "peach flat ()" in item["labels"]:
    item["labels"]= [label.replace("peach flat ()", "peach flat") for label in item["labels"]]

json_file_path = os.path.join(base_dir,  'Training_data_updated.json')

with open(json_file_path, 'w') as json_file:
    json.dump(dataset, json_file)

# %% [markdown]
# April 11, 2024: Creating new jsons for training composite fruits-360 and webscraped images

# %%
import os, json, re
def create_json_for_dataset_fruits360_new(dataset_type):
  num_imgs = 0
  dataset = []

  base_dir = f"/content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/{dataset_type}"

  # iterate through all the individual folders and find the dataset_type
  categories = [f for f in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, f))]
  # categories_paths = [os.path.join(base_dir, x) for x in categories]

  # print(categories)
  # return

  for category in categories:
    category_path = os.path.join(base_dir, category)
    # print(category_path)
    # return

    if os.path.exists(category_path):
      for file_name in os.listdir(category_path):
        num_imgs += 1
        if not file_name.endswith(".jpg"): # filter out non-jpg images
          continue
        # print(file_path)

        cleaned_category = re.sub(r'\d+', '', category).strip().replace("_", " ").lower()
        image_id = os.path.splitext(file_name)[0]
        data_entry = {
            "image_id" : image_id,
            "file_path": os.path.join('./',os.path.relpath(category_path, base_dir),file_name),
            "labels" : [cleaned_category] # just the directory name
        }
        dataset.append(data_entry)
        # print(data_entry)
    # print(category)

  # Write out json
  json_file_path = os.path.join(base_dir,  f'{dataset_type}_data_april_11.json')
  with open(json_file_path, 'w') as json_file:
    json.dump(dataset, json_file)

  print(f"Created {json_file_path}")
  print(num_imgs)

# %%
create_json_for_dataset_fruits360_new('Test')
# Out:
# Created /content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Test/Test_data_april_11.json
# 23027

# %%
create_json_for_dataset_fruits360_new('Training')
# Out:
# Created /content/drive/MyDrive/Applied CV Project/fruits-360_dataset/fruits-360/Training/Training_data_april_11.json
# 69167
